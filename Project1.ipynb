# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline
sns.set_style("darkgrid")

# %%
# country codes conversion
country_csv = ("country_codes.csv")
country_df = pd.read_csv(country_csv)
country_df2 = country_df[["Alpha-2 code","Alpha-3 code"]].copy()
country_df3 = country_df2.rename(columns={'Alpha-3 code': 'NOC'}, inplace = False)
country_df3.head()
# Out:
#   Alpha-2 code  NOC
# 0           AF  AFG
# 1           AX  ALA
# 2           AL  ALB
# 3           DZ  DZA
# 4           AS  ASM

# %%
path = ("athlete_events.csv")
df_events = pd.read_csv(path)


#df_events["join_id"] = df_events["NOC"] + df_events["Year"].astype(str)
# summer_df = df_events[df_events['Season'] == 'Summer']
# summer_df["BMI"] = summer_df["Weight"]/((summer_df["Height"]/100)**2)
# Add numerical value for medals? 3 = gold, 2= silver, 1 bronze and no medal = 0
df_events_a = pd.merge(df_events, country_df3, on="NOC")

df_events_a.head(10)
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
# 5  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
# 6  3605    An Weijiang   M  22.0   178.0    72.0  China  CHN  2006 Winter
# 7  3605    An Weijiang   M  22.0   178.0    72.0  China  CHN  2006 Winter
# 8  3610      An Yulong   M  19.0   173.0    70.0  China  CHN  1998 Winter
# 9  3610      An Yulong   M  19.0   173.0    70.0  China  CHN  1998 Winter
#
#    Year  Season            City                      Sport  \
# 0  1992  Summer       Barcelona                 Basketball
# 1  2012  Summer          London                       Judo
# 2  2000  Summer          Sydney                     Boxing
# 3  2004  Summer          Athina                  Wrestling
# 4  2016  Summer  Rio de Janeiro                   Swimming
# 5  2016  Summer  Rio de Janeiro                   Swimming
# 6  2006  Winter          Torino              Speed Skating
# 7  2006  Winter          Torino              Speed Skating
# 8  1998  Winter          Nagano  Short Track Speed Skating
# 9  1998  Winter          Nagano  Short Track Speed Skating
#
#                                              Event   Medal Alpha-2 code
# 0                      Basketball Men's Basketball     NaN           CN
# 1                     Judo Men's Extra-Lightweight     NaN           CN
# 2                        Boxing Men's Middleweight     NaN           CN
# 3         Wrestling Men's Lightweight, Greco-Roman     NaN           CN
# 4            Swimming Women's 200 metres Freestyle     NaN           CN
# 5  Swimming Women's 4 x 200 metres Freestyle Relay     NaN           CN
# 6                   Speed Skating Men's 500 metres     NaN           CN
# 7                 Speed Skating Men's 1,000 metres     NaN           CN
# 8       Short Track Speed Skating Men's 500 metres  Silver           CN
# 9     Short Track Speed Skating Men's 1,000 metres     NaN           CN

# %%
path3 = ("country_lat_long.csv")
lat_long_df = pd.read_csv(path3)
lat_long_df2 = lat_long_df.rename(columns={'country': 'Alpha-2 code'})

df_events_b = pd.merge(df_events_a, lat_long_df2, on="Alpha-2 code")
df_events_b.head()
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#    Year  Season            City       Sport  \
# 0  1992  Summer       Barcelona  Basketball
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal Alpha-2 code  latitude  \
# 0               Basketball Men's Basketball   NaN           CN  35.86166
# 1              Judo Men's Extra-Lightweight   NaN           CN  35.86166
# 2                 Boxing Men's Middleweight   NaN           CN  35.86166
# 3  Wrestling Men's Lightweight, Greco-Roman   NaN           CN  35.86166
# 4     Swimming Women's 200 metres Freestyle   NaN           CN  35.86166
#
#     longitude   name
# 0  104.195397  China
# 1  104.195397  China
# 2  104.195397  China
# 3  104.195397  China
# 4  104.195397  China

# %%
# May not need the cells below

# %%
# display just the columns needed to look at age over time
age_df = summer_df[["ID","Name","Sex","Age","Sport","Event","Year"]].copy()
age_df = age_df[age_df['Age'].notna()]
age_df.shape
age_df.head()

# %%
# women and age 
age_df_f = age_df[(age_df.Sex == "F")]
age_df_f.shape

# %%
chart = sns.boxplot(x='Year', y='Age', data = age_df_f )
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.xlabel("Olympic Year", fontsize= 12)
plt.ylabel("Athlete Age", fontsize= 12)
plt.title("Age vs Olympic Year Held (Women)", fontsize= 15)

# %%
chart = sns.boxplot(x='Sport', y='Age', data = age_df_f )
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.xlabel("Sport", fontsize= 12)
plt.ylabel("Athlete Age", fontsize= 12)
plt.title("Age vs Sport (Women)", fontsize= 15)

# %%
# How many sports for female athletes?

sport_list = age_df_f["Sport"].value_counts()
sport_list

# %%
# how many events for female athletes?
event_list_w = age_df_f["Event"].nunique()
event_list_w

# %%
# women and age only Athletics
age_df_f_ath = age_df[(age_df.Sport == "Athletics")]
age_df_f_ath.head()

# %%
# men and age 
age_df_m = age_df[(age_df.Sex == "M")]
age_df_m.shape
age_df_m.head()

# %%
## BMI

# %%
# display just the columns needed to look at BMI over time
bmi_df = summer_df[["ID","Name","Sex","BMI","Sport","Event","Year"]].copy()
bmi_df = bmi_df[bmi_df['BMI'].notna()]
bmi_df.shape
bmi_df.head()

# %%
# BMI for female athletes
bmi_df_f = bmi_df[(bmi_df.Sex == "F")]
bmi_df_f

# %%
# BMI for male athletes
bmi_df_m = bmi_df[(bmi_df.Sex == "M")]
bmi_df_m
